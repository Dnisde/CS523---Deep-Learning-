# %%
import os
import torch
import numpy as np
import skimage.transform
import matplotlib.pyplot as plt
from easydict import EasyDict as edict

from main_monodepth_pytorch import Model
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# # Monodepth

# %% [markdown]
# ## Train

# %% [markdown]
# Check if CUDA is available

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.device_count()
# Out:
# 1

# %%
torch.cuda.empty_cache()

# %%
dict_parameters = edict({'data_dir':'MonoDepth-PyTorch/data/kitti/train/',
                         'val_data_dir':'MonoDepth-PyTorch/data/kitti/val/',
                         'model_path':'MonoDepth-PyTorch/data/models/monodepth_resnet18_001.pth',
                         'output_directory':'MonoDepth-PyTorch/data/output/',
                         'input_height':256,
                         'input_width':512,
                         'model':'resnet18_md',
                         'pretrained':True,
                         'mode':'train',
                         'epochs':200,
                         'learning_rate':1e-4,
                         'batch_size': 8,
                         'adjust_lr':True,
                         'device':'cuda:0',
                         'do_augmentation':True,
                         'augment_parameters':[0.8, 1.2, 0.5, 2.0, 0.8, 1.2],
                         'print_images':False,
                         'print_weights':False,
                         'input_channels': 3,
                         'num_workers': 8,
                         'use_multiple_gpu': False})

# %%
model = Model(dict_parameters)
#model.load('data/models/monodepth_resnet18_001_last.pth')
# Out:
# Use a dataset with 4400 images
# Use a dataset with 37982 images

# %%
model.train()
# Out:
# Val_loss: 2.9395494729822333
# Epoch: 1 train_loss: 2.6143263557763103 val_loss: 2.266176734837619 time: 1274.43 s
# Model_saved
# Epoch: 2 train_loss: 2.1812624205446225 val_loss: 1.8680015960606662 time: 1262.92 s
# Model_saved
# Epoch: 3 train_loss: 1.8095679761209569 val_loss: 1.6083945575627414 time: 1263.896 s
# Model_saved
# Epoch: 4 train_loss: 1.5697765532379047 val_loss: 1.3768771481513977 time: 1274.294 s
# Model_saved
# Epoch: 5 train_loss: 1.3518465429640176 val_loss: 1.2251502628759905 time: 1260.219 s
# Model_saved
# Epoch: 6 train_loss: 1.1700516625494197 val_loss: 1.1001336851986971 time: 1256.705 s
# Model_saved
# Epoch: 7 train_loss: 1.0534991467145312 val_loss: 1.0618152077631517 time: 1261.018 s
# Model_saved
# Epoch: 8 train_loss: 0.9927836394750653 val_loss: 1.0098486238176172 time: 1259.008 s
# Model_saved
# Epoch: 9 train_loss: 0.9566895957995186 val_loss: 1.0097456537593494 time: 1260.825 s
# Model_saved
# Epoch: 10 train_loss: 0.9356652360838502 val_loss: 0.9793844945864244 time: 1264.71 s
# Model_saved
# Epoch: 11 train_loss: 0.9193207360162635 val_loss: 0.9928152389959856 time: 1262.755 s
# Epoch: 12 train_loss: 0.9046565303242067 val_loss: 0.9318998031182723 time: 1264.819 s
# Model_saved
# Epoch: 13 train_loss: 0.889751575838163 val_loss: 0.9422216191075065 time: 1267.298 s
# Epoch: 14 train_loss: 0.881953445984147 val_loss: 0.938618186712265 time: 1357.017 s
# Epoch: 15 train_loss: 0.8702014901678079 val_loss: 0.9734107439084486 time: 1306.108 s
# Epoch: 16 train_loss: 0.8654438189486996 val_loss: 0.9292930135943673 time: 1277.818 s
# Model_saved

# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 96, in _worker_loop
#     r = index_queue.get(timeout=MANAGER_STATUS_CHECK_INTERVAL)
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 96, in _worker_loop
#     r = index_queue.get(timeout=MANAGER_STATUS_CHECK_INTERVAL)
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 96, in _worker_loop
#     r = index_queue.get(timeout=MANAGER_STATUS_CHECK_INTERVAL)
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 96, in _worker_loop
#     r = index_queue.get(timeout=MANAGER_STATUS_CHECK_INTERVAL)
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 96, in _worker_loop
#     r = index_queue.get(timeout=MANAGER_STATUS_CHECK_INTERVAL)
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 106, in _worker_loop
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 96, in _worker_loop
#     r = index_queue.get(timeout=MANAGER_STATUS_CHECK_INTERVAL)
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/queues.py", line 104, in get
#     if not self._poll(timeout):
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/queues.py", line 104, in get
#     if not self._poll(timeout):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-c72315b99576> in <module>
# ----> 1 model.train()
#
# /projectnb2/dl523/projects/monodepth/MonoDepth-PyTorch/main_monodepth_pytorch.py in train(self)
#     201                 loss = self.loss_function(disps, [left, right])
#     202                 loss.backward()
# --> 203                 self.optimizer.step()
#     204                 losses.append(loss.item())
#     205
#
# /projectnb2/dl523/projects/monodepth/env/lib/python3.6/site-packages/torch/optim/adam.py in step(self, closure)
#      90
#      91                 # Decay the first and second moment running average coefficient
# ---> 92                 exp_avg.mul_(beta1).add_(1 - beta1, grad)
#      93                 exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
#      94                 if amsgrad:
#
# KeyboardInterrupt:
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 106, in _worker_loop
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/queues.py", line 104, in get
#     if not self._poll(timeout):
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/queues.py", line 104, in get
#     if not self._poll(timeout):
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/queues.py", line 104, in get
#     if not self._poll(timeout):
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 106, in <listcomp>
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/queues.py", line 104, in get
#     if not self._poll(timeout):
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/connection.py", line 257, in poll
#     return self._poll(timeout)
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/connection.py", line 257, in poll
#     return self._poll(timeout)
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 106, in <listcomp>
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/connection.py", line 257, in poll
#     return self._poll(timeout)
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/connection.py", line 257, in poll
#     return self._poll(timeout)
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/connection.py", line 257, in poll
#     return self._poll(timeout)
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/site-packages/torch/utils/data/dataset.py", line 81, in __getitem__
#     return self.datasets[dataset_idx][sample_idx]
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/connection.py", line 257, in poll
#     return self._poll(timeout)
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/connection.py", line 414, in _poll
#     r = wait([self], timeout)
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/connection.py", line 414, in _poll
#     r = wait([self], timeout)
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/site-packages/torch/utils/data/dataset.py", line 81, in __getitem__
#     return self.datasets[dataset_idx][sample_idx]
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/connection.py", line 414, in _poll
#     r = wait([self], timeout)
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/connection.py", line 414, in _poll
#     r = wait([self], timeout)
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/connection.py", line 414, in _poll
#     r = wait([self], timeout)
#   File "/projectnb2/dl523/projects/monodepth/MonoDepth-PyTorch/data_loader.py", line 31, in __getitem__
#     sample = self.transform(sample)
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/connection.py", line 414, in _poll
#     r = wait([self], timeout)
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/connection.py", line 911, in wait
#     ready = selector.select(timeout)
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/connection.py", line 911, in wait
#     ready = selector.select(timeout)
#   File "/projectnb2/dl523/projects/monodepth/MonoDepth-PyTorch/data_loader.py", line 31, in __getitem__
#     sample = self.transform(sample)
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/connection.py", line 911, in wait
#     ready = selector.select(timeout)
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/connection.py", line 911, in wait
#     ready = selector.select(timeout)
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/connection.py", line 911, in wait
#     ready = selector.select(timeout)
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/site-packages/torchvision/transforms/transforms.py", line 49, in __call__
#     img = t(img)
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/selectors.py", line 376, in select
#     fd_event_list = self._poll.poll(timeout)
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/multiprocessing/connection.py", line 911, in wait
#     ready = selector.select(timeout)
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/selectors.py", line 376, in select
#     fd_event_list = self._poll.poll(timeout)
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/site-packages/torchvision/transforms/transforms.py", line 49, in __call__
#     img = t(img)
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/selectors.py", line 376, in select
#     fd_event_list = self._poll.poll(timeout)
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/selectors.py", line 376, in select
#     fd_event_list = self._poll.poll(timeout)
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/selectors.py", line 376, in select
#     fd_event_list = self._poll.poll(timeout)
#   File "/projectnb2/dl523/projects/monodepth/MonoDepth-PyTorch/transforms.py", line 113, in __call__
#     right_image_aug = right_image ** random_gamma
# KeyboardInterrupt
#   File "/projectnb2/dl523/projects/monodepth/env/lib/python3.6/selectors.py", line 376, in select
#     fd_event_list = self._poll.poll(timeout)
#   File "/projectnb2/dl523/projects/monodepth/MonoDepth-PyTorch/transforms.py", line 123, in __call__
#     left_image_aug[i, :, :] *= random_colors[i]
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt

# %% [markdown]
# ## Test the model

# %%
dict_parameters_test = edict({'data_dir':'MonoDepth-PyTorch/data/test',
                              'model_path':'MonoDepth-PyTorch/data/models/monodepth_resnet18_001.pth',
                              'output_directory':'MonoDepth-PyTorch/data/output/IMG_5014_pretrained',
                              'input_height':256,
                              'input_width':512,
                              'model':'resnet18_md',
                              'pretrained':False,
                              'mode':'test',
                              'device':'cuda:0',
                              'input_channels':3,
                              'num_workers':4,
                              'use_multiple_gpu':False})
model_test = Model(dict_parameters_test)
# Out:
# Use a dataset with 300 images

# %%
model_test.test()
# Out:
# Finished Testing

# %%
disp = np.load('MonoDepth-PyTorch/data/output/IMG_5014_pretrained/disparities_pp.npy')  # Or disparities.npy for output without post-processing
disp.shape
# Out:
# (300, 256, 512)

# %%
disp_to_img = skimage.transform.resize(disp[0].squeeze(), [375, 1242], mode='constant')
plt.imshow(disp_to_img, cmap='plasma')

# %% [markdown]
# Save a color image

# %%
plt.imsave(os.path.join(dict_parameters_test.output_directory,
                        dict_parameters_test.model_path.split('/')[-1][:-4]+'_test_output.png'), disp_to_img, cmap='plasma')

# %% [markdown]
# Save all test images

# %%
for i in range(disp.shape[0]):
    disp_to_img = skimage.transform.resize(disp[i].squeeze(), [375, 1242], mode='constant')
    plt.imsave(os.path.join(dict_parameters_test.output_directory,
               'pred_'+str(i)+'.png'), disp_to_img, cmap='plasma')

# %% [markdown]
# Save a grayscale image

# %%
plt.imsave(os.path.join(dict_parameters_test.output_directory,
                        dict_parameters_test.model_path.split('/')[-1][:-4]+'_gray.png'), disp_to_img, cmap='gray')
